# %% [markdown]
# # Load Packages & Lib.

# %%
import torch
from transformers import BertTokenizer, BertForMaskedLM, BertConfig,AutoTokenizer
from torch.utils.data import DataLoader, Dataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import os

curr_path = os.getcwd()

# %% [markdown]
# # Data Load

# %%
# 데이터 세트 불러오기
df = pd.read_csv(os.path.join(curr_path,'artwork_data.csv')) # 환경에 맞게 수정해주십쇼!

# 몇 개 샘플 시각화
print(df.head())
# Out:
#        Artist Name                                      Artwork Title  \
# 0  Berenice Abbott                                       Eugène Atget
# 1  Berenice Abbott                                Jean Cocteau, Paris
# 2  Berenice Abbott                                Nightview, New York
# 3  Berenice Abbott  Canyon: Broadway and Exchange Place, New York ...
# 4  Berenice Abbott  Gunsmith and Police Department Headquarters, 6...
#
#                                  Artwork Description
# 0  In this portrait, Eugène Atget, with a bemused...
# 1  Berenice Abbott portrays Jean Cocteau, French ...
# 2  Abbott's photograph depicts the city of New Yo...
# 3  The image focuses on the facade of the Exchang...
# 4  This image of a shop sign captures Abbott's fa...

# %%
# 데이터셋 클래스 정의
class ArtDataset(Dataset):
    def __init__(self, descriptions, tokenizer, max_length):
        self.descriptions = descriptions
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.descriptions)

    def __getitem__(self, idx):
        description = self.descriptions[idx]
        inputs = self.tokenizer.encode_plus(
            description,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors="pt"
        )
        return inputs['input_ids'].squeeze(0), inputs['attention_mask'].squeeze(0)


# 데이터 로드
descriptions = df['Artwork Description'].tolist()  # 설명 텍스트 컬럼 이름

# %%
# 토큰화
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
max_length = 512  # BERT 입력 최대 길이

# %%
# 데이터셋 및 데이터로더 준비
dataset = ArtDataset(descriptions, tokenizer, max_length)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# # Model

# %%
# BERT MLM 모델 로드
model = BertForMaskedLM.from_pretrained('bert-base-uncased')
model.cuda()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (transform_act_fn): GELUActivation()
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=30522, bias=True)
#     )
#   )
# )

# %%
epochs = 200
# 추가 필요 변수 정의
# 모델과 토크나이저를 저장할 디렉토리 생성
model_save_dir = os.path.join(curr_path,'models')
os.makedirs(model_save_dir, exist_ok=True)
best_model_path = os.path.join(model_save_dir,'best_model.pth')  # 최상의 모델을 저장할 경로
tokenizer_save_path = os.path.join(model_save_dir, 'tokenizer')

optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

best_loss = float('inf')
patience = 3
no_improvement = 0

# %%
# 모델 학습 진행
model.train()
for epoch in range(epochs):
    train_loss = 0
    for batch in train_loader:
        input_ids, attention_mask = batch
        input_ids, attention_mask = input_ids.cuda(), attention_mask.cuda()

        outputs = model(input_ids, attention_mask=attention_mask, labels=input_ids)
        loss = outputs.loss
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        torch.cuda.empty_cache()  # GPU 캐시 비우기

    # 에포크당 평균 손실 계산
    avg_train_loss = train_loss / len(train_loader)

    # 검증 데이터셋에서 성능 평가
    model.eval()
    with torch.no_grad():
        val_loss = 0
        for batch in val_loader:
            input_ids, attention_mask = batch
            input_ids, attention_mask = input_ids.cuda(), attention_mask.cuda()
            outputs = model(input_ids, attention_mask=attention_mask, labels=input_ids)
            val_loss += outputs.loss.item()

    avg_val_loss = val_loss / len(val_loader)

    print(f"Epoch {epoch+1}/{epochs}, Training Loss: {avg_train_loss}, Validation Loss: {avg_val_loss}")

    if avg_val_loss < best_loss:
        best_loss = avg_val_loss
        no_improvement = 0
        torch.save(model.state_dict(), best_model_path)  # 모델 상태 저장
        tokenizer.save_pretrained(tokenizer_save_path)  # 토크나이저 저장
        print("Saved Best Model and Tokenizer")
    else:
        no_improvement+=1
    # Early Stopping 체크
    if no_improvement == patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1/200, Training Loss: 1.0301819561021541, Validation Loss: 0.06786366245325874
# Saved Best Model and Tokenizer
# Epoch 2/200, Training Loss: 0.03576318872397515, Validation Loss: 0.019984886488493753
# Saved Best Model and Tokenizer
# Epoch 3/200, Training Loss: 0.015480947854525563, Validation Loss: 0.010959754478843772
# Saved Best Model and Tokenizer
# Epoch 4/200, Training Loss: 0.00954994658675434, Validation Loss: 0.007225397823597579
# Saved Best Model and Tokenizer
# Epoch 5/200, Training Loss: 0.0067068501757874864, Validation Loss: 0.005237742217586321
# Saved Best Model and Tokenizer
# Epoch 6/200, Training Loss: 0.004997071799641447, Validation Loss: 0.003979321836274774
# Saved Best Model and Tokenizer
# Epoch 7/200, Training Loss: 0.0038944634178013945, Validation Loss: 0.0031657014863894265
# Saved Best Model and Tokenizer
# Epoch 8/200, Training Loss: 0.0031476177765167694, Validation Loss: 0.0025938077802386355
# Saved Best Model and Tokenizer
# Epoch 9/200, Training Loss: 0.002602507182181493, Validation Loss: 0.002179301919086891
# Saved Best Model and Tokenizer
# Epoch 10/200, Training Loss: 0.0021533351895441093, Validation Loss: 0.0018421372480909614
# Saved Best Model and Tokenizer
# Epoch 11/200, Training Loss: 0.001799678123285021, Validation Loss: 0.0015680148293647695
# Saved Best Model and Tokenizer
# Epoch 12/200, Training Loss: 0.001509363396412957, Validation Loss: 0.0013511417628786363
# Saved Best Model and Tokenizer
# Epoch 13/200, Training Loss: 0.0013011676235882036, Validation Loss: 0.0011802125800921418
# Saved Best Model and Tokenizer
# Epoch 14/200, Training Loss: 0.0011337066956260589, Validation Loss: 0.0010443229146082612
# Saved Best Model and Tokenizer
# Epoch 15/200, Training Loss: 0.001001293792253805, Validation Loss: 0.0009330600613098153
# Saved Best Model and Tokenizer
# Epoch 16/200, Training Loss: 0.0008906150699780781, Validation Loss: 0.0008403916846659473
# Saved Best Model and Tokenizer
# Epoch 17/200, Training Loss: 0.0007975008347377515, Validation Loss: 0.0007606261488570668
# Saved Best Model and Tokenizer
# Epoch 18/200, Training Loss: 0.0007166068246431732, Validation Loss: 0.0006930633133058162
# Saved Best Model and Tokenizer
# Epoch 19/200, Training Loss: 0.0006460643922058699, Validation Loss: 0.000634672211804975
# Saved Best Model and Tokenizer
# Epoch 20/200, Training Loss: 0.0005839485212475923, Validation Loss: 0.0005835543535581297
# Saved Best Model and Tokenizer
# Epoch 21/200, Training Loss: 0.0005293876966965427, Validation Loss: 0.0005385070732753614
# Saved Best Model and Tokenizer
# Epoch 22/200, Training Loss: 0.00048154966932644985, Validation Loss: 0.0004992917358108304
# Saved Best Model and Tokenizer
# Epoch 23/200, Training Loss: 0.00044146035089845587, Validation Loss: 0.0004657527315430343
# Saved Best Model and Tokenizer
# Epoch 24/200, Training Loss: 0.0003991370767427942, Validation Loss: 0.00042938050618806085
# Saved Best Model and Tokenizer
# Epoch 25/200, Training Loss: 0.0003645454384403915, Validation Loss: 0.00040282687233925303
# Saved Best Model and Tokenizer
# Epoch 26/200, Training Loss: 0.0003327482065912197, Validation Loss: 0.0003766252972555402
# Saved Best Model and Tokenizer
# Epoch 27/200, Training Loss: 0.000303643319708879, Validation Loss: 0.0003502598594744032
# Saved Best Model and Tokenizer
# Epoch 28/200, Training Loss: 0.00027693666729714666, Validation Loss: 0.0003282802384038565
# Saved Best Model and Tokenizer
# Epoch 29/200, Training Loss: 0.00025255536934649296, Validation Loss: 0.0003096597733126734
# Saved Best Model and Tokenizer
# Epoch 30/200, Training Loss: 0.00022961718928148802, Validation Loss: 0.00029115071725648115
# Saved Best Model and Tokenizer
# Epoch 31/200, Training Loss: 0.00020871881709204736, Validation Loss: 0.0002744065097752301
# Saved Best Model and Tokenizer
# Epoch 32/200, Training Loss: 0.00018949849716102732, Validation Loss: 0.0002563683845116483
# Saved Best Model and Tokenizer
# Epoch 33/200, Training Loss: 0.00017247481098739124, Validation Loss: 0.00024192151870332002
# Saved Best Model and Tokenizer
# Epoch 34/200, Training Loss: 0.0001580618211561675, Validation Loss: 0.0002283388830084518
# Saved Best Model and Tokenizer
# Epoch 35/200, Training Loss: 0.00014430663349461367, Validation Loss: 0.00021585382273769937
# Saved Best Model and Tokenizer
# Epoch 36/200, Training Loss: 0.00013376864542317604, Validation Loss: 0.00020334710044313825
# Saved Best Model and Tokenizer
# Epoch 37/200, Training Loss: 0.00012157664474867868, Validation Loss: 0.00019282811691107994
# Saved Best Model and Tokenizer
# Epoch 38/200, Training Loss: 0.0001120849046313183, Validation Loss: 0.0001835773828668821
# Saved Best Model and Tokenizer
# Epoch 39/200, Training Loss: 0.00010368321536181828, Validation Loss: 0.00017414549459799137
# Saved Best Model and Tokenizer
# Epoch 40/200, Training Loss: 9.611036316595916e-05, Validation Loss: 0.0001659460833573522
# Saved Best Model and Tokenizer
# Epoch 41/200, Training Loss: 8.922023682398096e-05, Validation Loss: 0.00015833831682410913
# Saved Best Model and Tokenizer
# Epoch 42/200, Training Loss: 8.302733927414363e-05, Validation Loss: 0.00015123857006341603
# Saved Best Model and Tokenizer
# Epoch 43/200, Training Loss: 7.73042554657823e-05, Validation Loss: 0.00014437439676839858
# Saved Best Model and Tokenizer
# Epoch 44/200, Training Loss: 7.266741172248087e-05, Validation Loss: 0.00013868509952718501
# Saved Best Model and Tokenizer
# Epoch 45/200, Training Loss: 6.799928448358446e-05, Validation Loss: 0.0001326785038733814
# Saved Best Model and Tokenizer
# Epoch 46/200, Training Loss: 6.361903327690097e-05, Validation Loss: 0.00012858547661915722
# Saved Best Model and Tokenizer
# Epoch 47/200, Training Loss: 5.9086536783803214e-05, Validation Loss: 0.0001225904912537183
# Saved Best Model and Tokenizer
# Epoch 48/200, Training Loss: 5.5212768597472735e-05, Validation Loss: 0.00011944244579353835
# Saved Best Model and Tokenizer
# Epoch 49/200, Training Loss: 5.2205827078476215e-05, Validation Loss: 0.00011355162036231966
# Saved Best Model and Tokenizer
# Epoch 50/200, Training Loss: 4.916086949541845e-05, Validation Loss: 0.00011118152917119646
# Saved Best Model and Tokenizer
# Epoch 51/200, Training Loss: 4.561854509676723e-05, Validation Loss: 0.00010581170082492891
# Saved Best Model and Tokenizer
# Epoch 52/200, Training Loss: 4.340063174252586e-05, Validation Loss: 0.00010329164508541854
# Saved Best Model and Tokenizer
# Epoch 53/200, Training Loss: 4.0111932185706125e-05, Validation Loss: 9.895755026852439e-05
# Saved Best Model and Tokenizer
# Epoch 54/200, Training Loss: 3.825876687622087e-05, Validation Loss: 9.884538549693603e-05
# Saved Best Model and Tokenizer
# Epoch 55/200, Training Loss: 3.596993883547839e-05, Validation Loss: 9.315134058637982e-05
# Saved Best Model and Tokenizer
# Epoch 56/200, Training Loss: 3.389533457496992e-05, Validation Loss: 9.194878941129632e-05
# Saved Best Model and Tokenizer
# Epoch 57/200, Training Loss: 3.163260099603604e-05, Validation Loss: 8.754037539534586e-05
# Saved Best Model and Tokenizer
# Epoch 58/200, Training Loss: 2.9940806544162578e-05, Validation Loss: 8.914365004302989e-05
# Epoch 59/200, Training Loss: 2.81044712848136e-05, Validation Loss: 8.29591103063328e-05
# Saved Best Model and Tokenizer
# Epoch 60/200, Training Loss: 2.6297024332826138e-05, Validation Loss: 8.51856401127674e-05
# Epoch 61/200, Training Loss: 2.4977039758406177e-05, Validation Loss: 7.854368585172137e-05
# Saved Best Model and Tokenizer
# Epoch 62/200, Training Loss: 2.3561017131676147e-05, Validation Loss: 7.764073325233767e-05
# Saved Best Model and Tokenizer
# Epoch 63/200, Training Loss: 2.243522568047655e-05, Validation Loss: 7.421733024624272e-05
# Saved Best Model and Tokenizer
# Epoch 64/200, Training Loss: 2.117931029742841e-05, Validation Loss: 7.7969375096847e-05
# Epoch 65/200, Training Loss: 2.013635611235001e-05, Validation Loss: 7.139783124062781e-05
# Saved Best Model and Tokenizer
# Epoch 66/200, Training Loss: 1.8893924252959333e-05, Validation Loss: 7.548232240557863e-05
# Epoch 67/200, Training Loss: 1.8073241579856327e-05, Validation Loss: 6.754218301306108e-05
# Saved Best Model and Tokenizer
# Epoch 68/200, Training Loss: 1.7410750727444183e-05, Validation Loss: 6.960056158705436e-05
# Epoch 69/200, Training Loss: 1.6157582955039192e-05, Validation Loss: 6.53659958516073e-05
# Saved Best Model and Tokenizer
# Epoch 70/200, Training Loss: 1.557240363866579e-05, Validation Loss: 6.735943653064383e-05
# Epoch 71/200, Training Loss: 1.4605301868271712e-05, Validation Loss: 6.19602794679796e-05
# Saved Best Model and Tokenizer
# Epoch 72/200, Training Loss: 1.453242646730088e-05, Validation Loss: 6.41371375957747e-05
# Epoch 73/200, Training Loss: 1.2696749430986854e-05, Validation Loss: 5.899701853409437e-05
# Saved Best Model and Tokenizer
# Epoch 74/200, Training Loss: 1.2461887308745645e-05, Validation Loss: 6.523209688513067e-05
# Epoch 75/200, Training Loss: 1.1416094264913865e-05, Validation Loss: 5.802585115709328e-05
# Saved Best Model and Tokenizer
# Epoch 76/200, Training Loss: 1.0852975210853862e-05, Validation Loss: 6.108486596691792e-05
# Epoch 77/200, Training Loss: 1.0300778916671198e-05, Validation Loss: 5.5949216830948205e-05
# Saved Best Model and Tokenizer
# Epoch 78/200, Training Loss: 9.885444253982383e-06, Validation Loss: 6.162979664569481e-05
# Epoch 79/200, Training Loss: 9.50746403868291e-06, Validation Loss: 5.3889831285821e-05
# Saved Best Model and Tokenizer
# Epoch 80/200, Training Loss: 9.178738876593641e-06, Validation Loss: 5.7351871472586505e-05
# Epoch 81/200, Training Loss: 8.576432994449356e-06, Validation Loss: 5.118495251361524e-05
# Saved Best Model and Tokenizer
# Epoch 82/200, Training Loss: 8.420824145498805e-06, Validation Loss: 5.6673770600087556e-05
# Epoch 83/200, Training Loss: 7.607796268489641e-06, Validation Loss: 4.707162852087897e-05
# Saved Best Model and Tokenizer
# Epoch 84/200, Training Loss: 5.974488020462979e-06, Validation Loss: 4.5422924800090294e-05
# Saved Best Model and Tokenizer
# Epoch 85/200, Training Loss: 5.579506803959662e-06, Validation Loss: 4.4185665033450385e-05
# Saved Best Model and Tokenizer
# Epoch 86/200, Training Loss: 5.197243543948592e-06, Validation Loss: 4.301920865359802e-05
# Saved Best Model and Tokenizer
# Epoch 87/200, Training Loss: 4.8343880897941266e-06, Validation Loss: 4.1881111495540076e-05
# Saved Best Model and Tokenizer
# Epoch 88/200, Training Loss: 4.521308690174865e-06, Validation Loss: 4.1209495815136884e-05
# Saved Best Model and Tokenizer
# Epoch 89/200, Training Loss: 4.281233473261297e-06, Validation Loss: 4.0481252734239475e-05
# Saved Best Model and Tokenizer
# Epoch 90/200, Training Loss: 4.060526024075633e-06, Validation Loss: 3.982305727678228e-05
# Saved Best Model and Tokenizer
# Epoch 91/200, Training Loss: 3.83280090189336e-06, Validation Loss: 3.902225210046762e-05
# Saved Best Model and Tokenizer
# Epoch 92/200, Training Loss: 3.6248824515957913e-06, Validation Loss: 3.8443001933367614e-05
# Saved Best Model and Tokenizer
# Epoch 93/200, Training Loss: 3.451626636223097e-06, Validation Loss: 3.7847953662736365e-05
# Saved Best Model and Tokenizer
# Epoch 94/200, Training Loss: 3.263383793854524e-06, Validation Loss: 3.7095767552005674e-05
# Saved Best Model and Tokenizer
# Epoch 95/200, Training Loss: 2.9847021082855124e-06, Validation Loss: 3.6517435258996125e-05
# Saved Best Model and Tokenizer
# Epoch 96/200, Training Loss: 2.824477582207556e-06, Validation Loss: 3.6112035746448196e-05
# Saved Best Model and Tokenizer
# Epoch 97/200, Training Loss: 2.681390135387743e-06, Validation Loss: 3.564175585110848e-05
# Saved Best Model and Tokenizer
# Epoch 98/200, Training Loss: 2.552393082746065e-06, Validation Loss: 3.523499442374433e-05
# Saved Best Model and Tokenizer
# Epoch 99/200, Training Loss: 2.440070218979789e-06, Validation Loss: 3.4840393910224736e-05
# Saved Best Model and Tokenizer
# Epoch 100/200, Training Loss: 2.281005454753893e-06, Validation Loss: 3.442560129020849e-05
# Saved Best Model and Tokenizer
# Epoch 101/200, Training Loss: 2.1617020698314846e-06, Validation Loss: 3.4153275738818216e-05
# Saved Best Model and Tokenizer
# Epoch 102/200, Training Loss: 2.0747143441521578e-06, Validation Loss: 3.3909812426667055e-05
# Saved Best Model and Tokenizer
# Epoch 103/200, Training Loss: 1.952299312302893e-06, Validation Loss: 3.361763315430888e-05
# Saved Best Model and Tokenizer
# Epoch 104/200, Training Loss: 1.8058883614373114e-06, Validation Loss: 3.3268459132533974e-05
# Saved Best Model and Tokenizer
# Epoch 105/200, Training Loss: 1.6974853349947536e-06, Validation Loss: 3.3050659062476316e-05
# Saved Best Model and Tokenizer
# Epoch 106/200, Training Loss: 1.6313655588595821e-06, Validation Loss: 3.2783159788189497e-05
# Saved Best Model and Tokenizer
# Epoch 107/200, Training Loss: 1.5817210493281239e-06, Validation Loss: 3.247597101442486e-05
# Saved Best Model and Tokenizer
# Epoch 108/200, Training Loss: 1.462770335399285e-06, Validation Loss: 3.246139579673849e-05
# Saved Best Model and Tokenizer
# Epoch 109/200, Training Loss: 1.3509443917102355e-06, Validation Loss: 3.244374566774615e-05
# Saved Best Model and Tokenizer
# Epoch 110/200, Training Loss: 1.2911644409826687e-06, Validation Loss: 3.2271977939966315e-05
# Saved Best Model and Tokenizer
# Epoch 111/200, Training Loss: 1.2434810175241792e-06, Validation Loss: 3.208091337950571e-05
# Saved Best Model and Tokenizer
# Epoch 112/200, Training Loss: 1.1679653534341e-06, Validation Loss: 3.1913403090049326e-05
# Saved Best Model and Tokenizer
# Epoch 113/200, Training Loss: 1.1132080634416158e-06, Validation Loss: 3.1783148258187686e-05
# Saved Best Model and Tokenizer
# Epoch 114/200, Training Loss: 1.0661979248272555e-06, Validation Loss: 3.164965806611101e-05
# Saved Best Model and Tokenizer
# Epoch 115/200, Training Loss: 1.0222781270385894e-06, Validation Loss: 3.161275513133767e-05
# Saved Best Model and Tokenizer
# Epoch 116/200, Training Loss: 9.82351123829135e-07, Validation Loss: 3.1387620147009275e-05
# Saved Best Model and Tokenizer
# Epoch 117/200, Training Loss: 9.427207049754285e-07, Validation Loss: 3.1295531721966923e-05
# Saved Best Model and Tokenizer
# Epoch 118/200, Training Loss: 9.071780719927146e-07, Validation Loss: 3.112797726851782e-05
# Saved Best Model and Tokenizer
# Epoch 119/200, Training Loss: 8.726270902686215e-07, Validation Loss: 3.108773340861315e-05
# Saved Best Model and Tokenizer
# Epoch 120/200, Training Loss: 8.393784103598374e-07, Validation Loss: 3.10391479776145e-05
# Saved Best Model and Tokenizer
# Epoch 121/200, Training Loss: 8.0688019805288e-07, Validation Loss: 3.0783375087687946e-05
# Saved Best Model and Tokenizer
# Epoch 122/200, Training Loss: 7.749706880069914e-07, Validation Loss: 3.07312083173335e-05
# Saved Best Model and Tokenizer
# Epoch 123/200, Training Loss: 7.439858078594543e-07, Validation Loss: 3.063611379830303e-05
# Saved Best Model and Tokenizer
# Epoch 124/200, Training Loss: 7.140357485777306e-07, Validation Loss: 3.050994114480144e-05
# Saved Best Model and Tokenizer
# Epoch 125/200, Training Loss: 6.850053110346339e-07, Validation Loss: 3.045727233169975e-05
# Saved Best Model and Tokenizer
# Epoch 126/200, Training Loss: 6.550712832938474e-07, Validation Loss: 3.0370470948154808e-05
# Saved Best Model and Tokenizer
# Epoch 127/200, Training Loss: 6.18159130728817e-07, Validation Loss: 3.0349045463186913e-05
# Saved Best Model and Tokenizer
# Epoch 128/200, Training Loss: 5.842887051402165e-07, Validation Loss: 3.0200983019312844e-05
# Saved Best Model and Tokenizer
# Epoch 129/200, Training Loss: 5.661565381418388e-07, Validation Loss: 3.013488483816218e-05
# Saved Best Model and Tokenizer
# Epoch 130/200, Training Loss: 5.488511671548839e-07, Validation Loss: 3.003150005423884e-05
# Saved Best Model and Tokenizer
# Epoch 131/200, Training Loss: 5.315585549702356e-07, Validation Loss: 2.992616332248337e-05
# Saved Best Model and Tokenizer
# Epoch 132/200, Training Loss: 5.13945725142141e-07, Validation Loss: 2.983028854560764e-05
# Saved Best Model and Tokenizer
# Epoch 133/200, Training Loss: 4.97771259488082e-07, Validation Loss: 2.981453995770982e-05
# Saved Best Model and Tokenizer
# Epoch 134/200, Training Loss: 4.833257027505522e-07, Validation Loss: 2.9740003008234507e-05
# Saved Best Model and Tokenizer
# Epoch 135/200, Training Loss: 4.6950142527986095e-07, Validation Loss: 2.9779340394497922e-05
# Epoch 136/200, Training Loss: 4.5602991806661984e-07, Validation Loss: 2.9884292348135525e-05
# Epoch 137/200, Training Loss: 4.4418949797281087e-07, Validation Loss: 2.9875688678724627e-05
# Early stopping triggered

# %%
# 모델 및 토크나이저 불러오기
model = BertForMaskedLM.from_pretrained('bert-base-uncased')
model.load_state_dict(torch.load(best_model_path))
model.cuda()

tokenizer = AutoTokenizer.from_pretrained(tokenizer_save_path)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# 모델 평가
model.eval()
total_loss = 0
with torch.no_grad():
    for batch in val_loader:
        input_ids, attention_mask = batch
        input_ids, attention_mask = input_ids.cuda(), attention_mask.cuda()

        outputs = model(input_ids, attention_mask=attention_mask, labels=input_ids)
        total_loss += outputs.loss.item()

avg_loss = total_loss / len(val_loader)
print(f"Validation Loss: {avg_loss}")
# Out:
# Validation Loss: 2.9740003008234507e-05

# %% [markdown]
# ## 사전학습 모델 저장

# %%
# # 모델 저장하기

# model_save_path = "" # 환경에 맞게 수정해주십쇼!
# model.save_pretrained(model_save_path)

# # 토크나이저 저장하기
# tokenizer_save_path = "저장할 경로" # 환경에 맞게 수정해주십쇼!
# tokenizer.save_pretrained(tokenizer_save_path)

# %% [markdown]
# ## cf) 나중에 저장된 정보 불러오는 법

# %%
'''
# 저장된 모델 불러오기
model = BertForMaskedLM.from_pretrained(model_save_path)

# 저장된 토크나이저 불러오기
tokenizer = BertTokenizer.from_pretrained(tokenizer_save_path)
'''
# Out:
# '\n# 저장된 모델 불러오기\nmodel = BertForMaskedLM.from_pretrained(model_save_path)\n\n# 저장된 토크나이저 불러오기\ntokenizer = BertTokenizer.from_pretrained(tokenizer_save_path)\n'
