# %%
import torch
from torch.utils.data import Dataset, DataLoader, random_split, Subset
from transformers import BertTokenizer, BertForTokenClassification, BertConfig,BertForMaskedLM,BertConfig
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold,train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from seqeval.metrics import classification_report
from sklearn.metrics import confusion_matrix, classification_report, f1_score, roc_curve, auc
import seaborn as sns
from sklearn.preprocessing import label_binarize
from itertools import cycle
import os
from functools import partial
from io import StringIO
import ast

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    print ('Available devices :', torch.cuda.device_count())
    print ('Current cuda device :', torch.cuda.current_device())
    print(torch.cuda.get_device_name(device))
else:
    print("CUDA is not available. Model is running on CPU.")
    device = torch.device('cpu')
# Out:
# Available devices : 1
# Current cuda device : 0
# NVIDIA GeForce RTX 4090

# %%
curr_path = os.getcwd()
join_with_curr = partial(os.path.join, curr_path)

# %%
def path_check(dst_path ,base_name):
    check_path = os.path.join(dst_path,base_name)
    if not os.path.exists(check_path):
        os.mkdir(check_path)
        print(f"Create path : {check_path}")
        return check_path
    else:
        print(f"Path already exist : {check_path}")
        return check_path

# %%
class ArtDatasetForTokenClassification(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=512):
        self.descriptions = dataframe['description'].values
        self.labels = [ast.literal_eval(StringIO(word).getvalue()) for word in dataframe['word_labels_tuples'].values]
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __getitem__(self, idx):
        description = self.descriptions[idx]
        label = self.labels[idx]

        inputs = self.tokenizer.encode_plus(
            description,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors="pt"
        )

        # 레이블에 대한 패딩, 트렁크 처리
        label = label + ['O'] * (self.max_length - len(label))  # 레이블을 max_length에 맞게 패딩해주기
        label = label[:self.max_length]

        # 레이블을 텐서로 변환
        label_tensor = torch.tensor([label_encoder[l] for l in label], dtype=torch.long)  # label_encoder는 레이블을 숫자로 매핑하는 딕셔너리

        return inputs['input_ids'].squeeze(), inputs['attention_mask'].squeeze(), label_tensor

    def __len__(self):
        return len(self.descriptions)

# %%
# 예시 데이터 text = "The image depicts a chaotic and intense scene..."
# IOB 태그 할당 예시 labels = ["O", "O", "O", "B-theme", ...]
path_check_curr = partial(path_check, curr_path)
path_check_curr('IOB')
csv_file = join_with_curr('IOB','baroque_SF_IOB.csv')
# 데이터 파일 로드
df = pd.read_csv(csv_file)
# 예시 데이터 형식: 'sentence', 'word_labels'
df.head()
# Out:
# Path already exist : C:\Users\royal\Desktop\NLP_workbench\IOB
#    NO                                                img  \
# 0   1  Bella, Stefano della; Frontispiece for Il Merc...
# 1   2  Elder, Jan Brueghel the; Paradise Landscape wi...
# 2   3  Elder, Lucas Vorsterman the; Achilles and Pria...
# 3   4  Elder, Lucas Vorsterman the; Achilles and Pria...
# 4   5  Goltzius, Hendrick; Christ before Pilate from ...
#
#                                          description    genre  \
# 0  The image is a black and white engraving from ...  baroque
# 1  The image you've shown is a painting that is r...  baroque
# 2  The image you've shown appears to be a histori...  baroque
# 3  The image depicts an etching or engraving full...  baroque
# 4  This is a black and white etching with signifi...  baroque
#
#                 Human and Social Dynamics Artistic and Cultural Expressions  \
# 0                                 Unknown                 tradition, symbol
# 1                            Human, group                           Unknown
# 2                              individual                       crafts, art
# 3  individual, interaction, people, group                style, crafts, art
# 4     society, interaction, social, group                        style, art
#
#   Objects and Materials Conceptual and Philosophical Ideas  \
# 0               Unknown                       wisdom, idea
# 1              clothing                            Unknown
# 2               Unknown                            Unknown
# 3              clothing                            emotion
# 4              clothing                            emotion
#
#                   Natural and Environmental Elements  \
# 0                                      nature, plant
# 1  animal, sky, natural, environment, nature, lan...
# 2                            nature, sky, atmosphere
# 3                                    sky, atmosphere
# 4                                 nature, atmosphere
#
#                                       iob_tag_tuples  \
# 0  [('the', 'O'), ('image', 'O'), ('is', 'O'), ('...
# 1  [('the', 'O'), ('image', 'O'), ('you', 'O'), (...
# 2  [('the', 'O'), ('image', 'O'), ('you', 'O'), (...
# 3  [('the', 'O'), ('image', 'O'), ('depicts', 'O'...
# 4  [('this', 'O'), ('is', 'O'), ('a', 'O'), ('bla...
#
#                                   word_labels_tuples
# 0  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 1  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...

# %%
# 전체 데이터를 훈련 및 테스트 세트로 8:2로 분리
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# 설정
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# Cross-Validation을 위한 데이터 준비
descriptions = train_df['description'].tolist()
labels = train_df['word_labels_tuples'].tolist()

# %%
# 사전학습된 모델과 토크나이저 로드
# model_file = join_with_curr('models','best_model.pth')
tokenizer_path = join_with_curr('models','tokenizer')
tokenizer = BertTokenizer.from_pretrained(tokenizer_path)
num_labels = 6
max_length = 512

# %%
# 라벨 인코더 만들기: 레이블을 숫자로 매핑하는 딕셔너리 생성 ## 추가한 부분!
unique_labels = set()  # 레이블 저장 집합 만들어 놓기

for labels in train_df['word_labels_tuples']:  # 모든 레이블 돌아가면서 순회
    unique_labels.update(ast.literal_eval(labels))

label_encoder = {label: idx for idx, label in enumerate(unique_labels)}

# %%
config = BertConfig.from_pretrained('oceanstar/pretrained_for_art_domain',token = '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', num_labels=num_labels)

model = BertForTokenClassification(config)
model.cuda()
# Out:
# BertForTokenClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=6, bias=True)
# )

# %%
epochs = 10

# %%
# 모든 레이블을 확인하는 코드 (확인용이니 굳이 실행 안하셔도 됩니다.)
all_labels = []
for labels in train_df['word_labels_tuples']:
    all_labels.extend(ast.literal_eval(labels))

label_set = set(all_labels)
print("Unique labels:", label_set)
print("Are all labels within range 0 to num_labels-1?", all(label in range(num_labels) for label in label_set))
# Out:
# Unique labels: {'B-Natural_and_Environmental_Elements', 'B-Artistic_and_Cultural_Expressions', 'B-Human_and_Social_Dynamics', 'O', 'B-Objects_and_Materials', 'B-Conceptual_and_Philosophical_Ideas'}
# Are all labels within range 0 to num_labels-1? False

# %%
batch_size = 16

# loss 기록을 위한 리스트
fold_perf = {}

for fold, (train_ids, val_ids) in enumerate(kf.split(descriptions)):
    print(f"FOLD {fold}")
    print("Train IDs range:", min(train_ids), "to", max(train_ids))
    print("Validation IDs range:", min(val_ids), "to", max(val_ids))
    print("--------------------------------")

    # train_df에서 서브셋을 추출하고 인덱스를 재조정합니다.
    train_subset_df = train_df.iloc[train_ids].reset_index(drop=True)
    val_subset_df = train_df.iloc[val_ids].reset_index(drop=True)

    # Subset을 사용하여 학습과 검증 데이터셋을 만듭니다.
    train_subset = Subset(ArtDatasetForTokenClassification(train_subset_df, tokenizer, max_length), range(len(train_ids)))
    val_subset = Subset(ArtDatasetForTokenClassification(val_subset_df, tokenizer, max_length), range(len(val_ids)))

    # DataLoader를 정의합니다.
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=batch_size)

    # 모델 및 최적화 알고리즘 초기화
    model = BertForTokenClassification(config)
    model.cuda()
    optimizer = torch.optim.Adam(params=model.parameters(), lr=3e-5)

    # 각 fold의 학습 진행
    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for step, batch in enumerate(train_loader):
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)
            b_labels = b_labels.to(device)

            # Forward pass
            optimizer.zero_grad()
            outputs = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask, labels=b_labels)
            loss = outputs[0]
            total_loss += loss.item()

            # Backward pass
            loss.backward()
            optimizer.step()

        # 평균 손실 계산
        avg_train_loss = total_loss / len(train_loader)
        print(f"Average training loss: {avg_train_loss}")

        # 검증 데이터에 대한 평가
        model.eval()
        eval_loss = 0

        for batch in val_loader:
            b_input_ids, b_input_mask, b_labels = batch
            b_input_ids = b_input_ids.to(device)
            b_input_mask = b_input_mask.to(device)
            b_labels = b_labels.to(device)

            with torch.no_grad():
                outputs = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask, labels=b_labels)

            eval_loss += outputs[0].item()

        # 평균 손실 계산
        avg_val_loss = eval_loss / len(val_loader)
        print(f"Validation loss: {avg_val_loss}")
        fold_perf[fold] = {'train_loss': avg_train_loss, 'val_loss': avg_val_loss}

print(fold_perf)
# Out:
# FOLD 0
# Train IDs range: 1 to 399
# Validation IDs range: 0 to 396
# --------------------------------
# Average training loss: 0.18678498789668083
# Validation loss: 0.0834305927157402
# Average training loss: 0.08348522242158651
# Validation loss: 0.08289914056658745
# Average training loss: 0.0825660664588213
# Validation loss: 0.08294347226619721
# Average training loss: 0.08247214108705521
# Validation loss: 0.08248764500021935
# Average training loss: 0.08212487399578094
# Validation loss: 0.08196191787719727
# Average training loss: 0.08212737515568733
# Validation loss: 0.08248728439211846
# Average training loss: 0.08184067904949188
# Validation loss: 0.08229323327541352
# Average training loss: 0.08111163079738617
# Validation loss: 0.08180692568421363
# Average training loss: 0.0801544638350606
# Validation loss: 0.08172860741615295
# Average training loss: 0.07836878821253776
# Validation loss: 0.08435811176896095
# FOLD 1
# Train IDs range: 0 to 399
# Validation IDs range: 3 to 398
# --------------------------------
# Average training loss: 0.17850652039051057
# Validation loss: 0.08770505487918853
# Average training loss: 0.08221980445086956
# Validation loss: 0.08629457205533982
# Average training loss: 0.08171013072133064
# Validation loss: 0.08602403998374938
# Average training loss: 0.08153076972812415
# Validation loss: 0.08569466471672058
# Average training loss: 0.08131061606109143
# Validation loss: 0.08562885373830795
# Average training loss: 0.08118666838854552
# Validation loss: 0.0851625606417656
# Average training loss: 0.0805775722488761
# Validation loss: 0.08501569032669068
# Average training loss: 0.0797688502818346
# Validation loss: 0.08528226613998413
# Average training loss: 0.07868785113096237
# Validation loss: 0.08548303991556168
# Average training loss: 0.07731766290962697
# Validation loss: 0.08615515381097794
# FOLD 2
# Train IDs range: 0 to 399
# Validation IDs range: 2 to 392
# --------------------------------
# Average training loss: 0.19506674576550723
# Validation loss: 0.08857400268316269
# Average training loss: 0.08297585882246494
# Validation loss: 0.08685799837112426
# Average training loss: 0.08148766402155161
# Validation loss: 0.08603357970714569
# Average training loss: 0.08140958249568939
# Validation loss: 0.08639453500509262
# Average training loss: 0.08123869746923447
# Validation loss: 0.08628458678722381
# Average training loss: 0.08087367974221707
# Validation loss: 0.08518968373537064
# Average training loss: 0.08038287796080112
# Validation loss: 0.08506709784269333
# Average training loss: 0.07954377867281437
# Validation loss: 0.08470790386199951
# Average training loss: 0.07891438696533441
# Validation loss: 0.0867027223110199
# Average training loss: 0.07773462459444999
# Validation loss: 0.0859324425458908
# FOLD 3
# Train IDs range: 0 to 399
# Validation IDs range: 4 to 389
# --------------------------------
# Average training loss: 0.21695281732827426
# Validation loss: 0.07450231760740281
# Average training loss: 0.08532223664224148
# Validation loss: 0.0747557207942009
# Average training loss: 0.0846070859581232
# Validation loss: 0.07420723289251327
# Average training loss: 0.08449386693537235
# Validation loss: 0.07439391911029816
# Average training loss: 0.08440032862126827
# Validation loss: 0.07405412644147873
# Average training loss: 0.08425063975155353
# Validation loss: 0.07368041425943375
# Average training loss: 0.08390988297760486
# Validation loss: 0.07435733675956727
# Average training loss: 0.08363659121096134
# Validation loss: 0.07309920191764832
# Average training loss: 0.08236665539443493
# Validation loss: 0.07360100895166397
# Average training loss: 0.08132733441889287
# Validation loss: 0.0735096886754036
# FOLD 4
# Train IDs range: 0 to 398
# Validation IDs range: 1 to 399
# --------------------------------
# Average training loss: 0.19225369282066823
# Validation loss: 0.08567353934049607
# Average training loss: 0.08387612923979759
# Validation loss: 0.08314130306243897
# Average training loss: 0.08252090513706208
# Validation loss: 0.08229006081819534
# Average training loss: 0.08239720612764359
# Validation loss: 0.08216893076896667
# Average training loss: 0.08215156309306622
# Validation loss: 0.08220845907926559
# Average training loss: 0.08180200997740031
# Validation loss: 0.08297521770000457
# Average training loss: 0.08176309075206518
# Validation loss: 0.08194108307361603
# Average training loss: 0.08097273875027895
# Validation loss: 0.08361830115318299
# Average training loss: 0.0801906730979681
# Validation loss: 0.0825314462184906
# Average training loss: 0.07874817252159119
# Validation loss: 0.08272689580917358
# {0: {'train_loss': 0.07836878821253776, 'val_loss': 0.08435811176896095}, 1: {'train_loss': 0.07731766290962697, 'val_loss': 0.08615515381097794}, 2: {'train_loss': 0.07773462459444999, 'val_loss': 0.0859324425458908}, 3: {'train_loss': 0.08132733441889287, 'val_loss': 0.0735096886754036}, 4: {'train_loss': 0.07874817252159119, 'val_loss': 0.08272689580917358}}
